# %%
# !python generate_scaling_csv.py
# Out:
# Carregadas 5000 imagens para benchmark.
# Classes: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
#
# Benchmarking n_images = 100
#   baseline       0.533511 s
#   vectorized     0.021424 s
#   numba          155.659298 s
#   multiprocessing 0.338661 s
#   gpu            0.074875 s
#
# Benchmarking n_images = 500
#   baseline       2.959618 s
#   vectorized     0.050856 s
#   numba          178.429295 s
#   multiprocessing 0.863403 s
#   gpu            0.068519 s
#
# Benchmarking n_images = 1000
#   baseline       5.043876 s
#   vectorized     0.045710 s
#   numba          145.755080 s
#   multiprocessing 2.080195 s
#   gpu            0.091544 s
#
# Benchmarking n_images = 2000
#   baseline       10.113216 s
#   vectorized     0.061145 s
#   numba          146.485649 s
#   multiprocessing 3.902157 s
#   gpu            0.096003 s
#
# Benchmarking n_images = 5000
#   baseline       24.209586 s
#   vectorized     0.138423 s
# ...
