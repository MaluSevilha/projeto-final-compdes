# %% [markdown]
# # Projeto Final: Computação de Alto Desempenho
#
# Este notebook foi escrito para cumprir dois papéis ao mesmo tempo:
#
# 1. servir como **roteiro de apresentação**;
# 2. funcionar como uma **entrega autônoma e reproduzível**.
#
# A ideia é que cada seção tenha:
# - contexto suficiente para alguém entender o problema sem ouvir a apresentação;
# - código para regenerar os principais resultados;
# - um bloco de interpretação para mostrar o que cada resultado significa.
#
# ## Estrutura
# 1. Problema e relevância
# 2. Base de dados
# 3. Solução inicial (baseline)
# 4. Gargalos identificados
# 5. Otimizações e ganho marginal
# 6. Comparação final e escalonamento
# 7. Conclusão

# %% [markdown]
# ## 1) Problema e relevância
#
# Processamento de imagens costuma parecer barato quando olhamos para uma única imagem, mas deixa de ser trivial quando a mesma sequência de operações precisa ser repetida milhares de vezes. Em visão computacional, isso aparece em tarefas como pré-processamento, filtragem, extração de bordas, normalização e preparação de dados para classificação.
#
# Neste projeto, o objetivo não foi treinar um classificador final. O foco foi medir, de forma controlada, **quanto custa processar imagens** quando mudamos a forma de implementação.
#
# ### Pergunta central
# O que acontece com o tempo de execução quando o mesmo pipeline é reescrito com estratégias diferentes?
#
# ### Pipeline estudado
# - leitura da base;
# - reconstrução do formato RGB;
# - conversão para escala de cinza;
# - detecção de bordas com Sobel.
#
# A escolha é propositalmente simples: o problema precisa ser pequeno o suficiente para caber em uma apresentação, mas grande o bastante para revelar diferenças reais de desempenho.
#
# ### O que vale destacar na apresentação
# - o pipeline é funcional antes de ser otimizado;
# - a comparação só é justa se a saída continuar equivalente;
# - o gargalo principal não está em “fazer mais coisa”, e sim em **fazer a mesma coisa de forma mais eficiente**.

# %% [markdown]
# ## 2) Base de dados
#
# A base usada é a **CIFAR-10**, um conjunto clássico de imagens coloridas muito comum em trabalhos introdutórios de visão computacional.
#
# ### Características principais
# - 60.000 imagens coloridas;
# - resolução de 32 × 32 pixels;
# - 10 classes;
# - 50.000 imagens de treino;
# - 10.000 imagens de teste.
#
# As classes são:
#
# `airplane`, `automobile`, `bird`, `cat`, `deer`, `dog`, `frog`, `horse`, `ship` e `truck`.
#
# ### Por que essa base é interessante aqui?
# Porque ela é pequena por imagem, mas grande no total. Isso faz com que a sobrecarga de loops, conversões e chamadas repetidas fique bem visível. Em outras palavras: é um bom cenário para comparar implementações.
#
# ### Representação interna
# Na versão Python da base, cada imagem é armazenada como um vetor de 3072 posições:
# - 1024 valores do canal vermelho;
# - 1024 do canal verde;
# - 1024 do canal azul.
#
# Durante o pipeline, esse vetor é reconstruído para `32 × 32 × 3`, o que permite aplicar as etapas de pré-processamento normalmente.
#
# ### Como apresentar essa seção
# A mensagem principal aqui é simples: **a base é pequena por unidade, mas o volume total faz a diferença aparecer**.

# %%
# Célula opcional: regenerar exemplos visuais da CIFAR-10 e salvar as figuras usadas na apresentação.
# Ajuste `data_dir` se a base estiver em outro caminho.

from pathlib import Path
import pickle
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

possible_dirs = [
    Path("cifar-10-batches-py"),
    Path("data/cifar-10-batches-py"),
    Path("datasets/cifar-10-batches-py"),
]

data_dir = next((p for p in possible_dirs if p.exists()), None)

label_names = [
    "airplane", "automobile", "bird", "cat", "deer",
    "dog", "frog", "horse", "ship", "truck",
]

fig_dir = Path("outputs/figures")
fig_dir.mkdir(parents=True, exist_ok=True)

def load_cifar_batch(batch_path: Path):
    with open(batch_path, "rb") as f:
        batch = pickle.load(f, encoding="bytes")
    images = batch[b"data"].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)
    labels = np.array(batch[b"labels"])
    return images, labels

if data_dir is None:
    print("Base CIFAR-10 não encontrada. Ajuste `data_dir` para o caminho local da base.")
else:
    train_batch = data_dir / "data_batch_1"
    images, labels = load_cifar_batch(train_batch)

    # 1) Exemplos da base
    fig, axes = plt.subplots(2, 4, figsize=(10, 5))
    for ax, idx in zip(axes.ravel(), range(8)):
        ax.imshow(images[idx])
        ax.set_title(label_names[labels[idx]])
        ax.axis("off")
    fig.suptitle("Exemplos da CIFAR-10")
    fig.tight_layout()
    fig.savefig(fig_dir / "exemplos_da_base.png", dpi=200, bbox_inches="tight")
    plt.show()

    # 2) Distribuição das classes
    counts = Counter(labels.tolist())
    xs = [label_names[i] for i in range(10)]
    ys = [counts[i] for i in range(10)]

    plt.figure(figsize=(10, 4))
    plt.bar(xs, ys)
    plt.title("Distribuição das classes no subconjunto carregado")
    plt.xticks(rotation=30, ha="right")
    plt.ylabel("Quantidade")
    plt.tight_layout()
    plt.savefig(fig_dir / "distribuicao_classes.png", dpi=200, bbox_inches="tight")
    plt.show()

    # 3) Representação interna de uma imagem
    sample = images[0]
    flattened = sample.transpose(2, 0, 1).reshape(-1)

    fig, axes = plt.subplots(1, 2, figsize=(10, 4))
    axes[0].imshow(sample)
    axes[0].set_title("Imagem reconstruída")
    axes[0].axis("off")

    axes[1].plot(flattened, linewidth=0.8)
    axes[1].set_title("Vetor interno (3072 valores)")
    axes[1].set_xlabel("Índice")
    axes[1].set_ylabel("Intensidade")
    fig.tight_layout()
    fig.savefig(fig_dir / "representacao_imagem.png", dpi=200, bbox_inches="tight")
    plt.show()

    print("Figuras salvas em:", fig_dir.resolve())

# %% [markdown]
# ## 3) Solução inicial: baseline
#
# A primeira versão foi feita em **Python puro**, com loops explícitos e organização modular. Ela é importante por dois motivos:
#
# 1. serve como referência de corretude;
# 2. fornece a linha de base para medir qualquer otimização depois.
#
# ### O que essa versão faz
# - carrega a base;
# - reconstrói as imagens no formato RGB;
# - converte para escala de cinza;
# - aplica Sobel;
# - mede o tempo de cada etapa.
#
# ### Por que começar por ela?
# Porque otimizar sem baseline não ajuda. Antes de pensar em velocidade, é preciso garantir que:
# - a implementação está correta;
# - a saída é estável;
# - o tempo medido é comparável entre versões.
#
# ### Mensagem para a apresentação
# A baseline não é a versão “boa”. Ela é a versão **necessária**: é a partir dela que os ganhos de cada otimização passam a ter significado.

# %%
# Rodar a solução inicial e mostrar tempos e proporções por etapa

from experiments.baseline.pipeline import process_pipeline

baseline = process_pipeline(dataset="cifar10", split="train", limit=5000)

stage_times = {
    "Load data": baseline.timings.load_data_s,
    "Reconstruct RGB": baseline.timings.reconstruct_rgb_s,
    "Preprocess": baseline.timings.preprocess_s,
}

print("=== Baseline ===")
print("Imagens processadas:", baseline.images_rgb.shape[0])
print("Shape RGB: ", baseline.images_rgb.shape)
print("Shape Gray:", baseline.images_gray.shape)
print("Shape Edges:", baseline.images_edges.shape)
print()

for name, value in stage_times.items():
    pct = (value / baseline.timings.total_s) * 100 if baseline.timings.total_s else 0
    print(f"{name:16s}: {value:.6f} s  ({pct:5.1f}%)")

print(f"{'Total':16s}: {baseline.timings.total_s:.6f} s")
print(f"{'Throughput':16s}: {baseline.images_rgb.shape[0] / baseline.timings.total_s:.2f} imagens/s")

# %% [markdown]
# ## 4) Gargalos identificados
#
# O profiling da baseline normalmente mostra que a maior parte do custo está concentrada no pré-processamento, especialmente nas operações que percorrem pixel por pixel em Python.
#
# ### Gargalos esperados / observados
# - Sobel em Python puro;
# - conversão para escala de cinza;
# - leitura e deserialização da base;
# - custo de compilação JIT na primeira execução do Numba, quando essa estratégia é usada sem warm-up.
#
# ### Como interpretar isso
# Se quase todo o tempo está no pré-processamento, então o ganho mais relevante não vem de “mexer em tudo”, mas de atacar o trecho mais repetido do pipeline.
#
# ### O que vale mostrar na apresentação
# - tabela do `cProfile`;
# - captura do Snakeviz;
# - tempo total versus tempo por etapa;
# - explicação do porquê o gargalo dominante faz sentido.

# %%
# Célula auxiliar para abrir perfis e mostrar o trecho mais caro de cada execução.

from pathlib import Path
import pstats

profile_files = [
    Path("outputs/profiling/baseline_profile.prof"),
    Path("outputs/profiling/numba_profile.prof"),
    Path("outputs/profiling/vectorized_profile.prof"),
    Path("outputs/profiling/multiprocessing_profile.prof"),
]

def show_profile(path: Path, top_n: int = 20):
    if not path.exists():
        print(f"[ausente] {path}")
        return
    print(f"\n=== {path.name} ===")
    stats = pstats.Stats(str(path))
    stats.sort_stats("cumtime").print_stats(top_n)

for p in profile_files:
    show_profile(p, top_n=15)

# %% [markdown]
# ## 5) Otimizações e ganho marginal
#
# A comparação aqui não deve ser só “antes versus depois”. O mais interessante é observar o **ganho marginal de cada nova estratégia**.
#
# ### Versões consideradas
# - **Baseline**: Python puro com loops;
# - **Numba**: aceleração via JIT;
# - **NumPy**: vetorização;
# - **Multiprocessing**: paralelização por blocos;
# - **GPU**: apenas se houver ambiente disponível e o custo de transferência compensar.
#
# ### O que comparar em cada etapa
# Para cada versão, vale responder:
# - o que foi alterado no código;
# - qual gargalo foi atacado;
# - quanto o tempo caiu em relação à versão anterior;
# - se a saída permaneceu equivalente.
#
# ### Leitura correta do “ganho marginal”
# Se uma versão ficou mais rápida que a anterior, isso não significa automaticamente que ela é a melhor em qualquer cenário. É preciso olhar:
# - custo de inicialização;
# - custo de compilação;
# - overhead de paralelização;
# - tamanho da entrada;
# - estabilidade do ganho conforme o número de imagens cresce.
#
# ### Mensagem para a apresentação
# O objetivo não é só mostrar aceleração. É mostrar **de onde vem a aceleração**.

# %%
# Gerar ou recarregar a comparação consolidada entre versões.

from pathlib import Path
import pandas as pd
import numpy as np

RUN_BENCHMARKS = False  # mude para True se quiser regenerar os CSVs da bancada

if RUN_BENCHMARKS:
    import subprocess, sys
    subprocess.run(
        [sys.executable, "-m", "benchmark.compare_versions_numba", "--repeat", "3", "--limit", "5000"],
        check=False,
    )

bench_dir = Path("outputs/benchmarks")

def find_first_csv(patterns):
    for pattern in patterns:
        matches = sorted(bench_dir.glob(pattern))
        if matches:
            return matches[0]
    return None

compare_csv = find_first_csv(["*compare*.csv", "*versions*.csv"])
if compare_csv is None:
    print("Nenhum CSV consolidado encontrado em outputs/benchmarks.")
else:
    df = pd.read_csv(compare_csv)

    def pick_col(frame, candidates):
        cols = list(frame.columns)
        lower_map = {c.lower(): c for c in cols}
        for cand in candidates:
            for low, original in lower_map.items():
                if cand in low:
                    return original
        return None

    version_col = pick_col(df, ["version", "versao", "variant", "name"])
    total_col = pick_col(df, ["mean_total_s", "total_s", "tempo_medio_s", "mean_time_s", "avg_total_s"])

    if version_col is None or total_col is None:
        print("CSV encontrado, mas não consegui identificar as colunas principais automaticamente.")
        display(df)
    else:
        # Mantém uma ordem intuitiva quando os nomes são conhecidos.
        preferred_order = ["baseline", "numba", "numpy", "vectorized", "multiprocessing", "gpu", "cuda"]
        df = df.copy()
        df["_order"] = df[version_col].astype(str).str.lower().map(
            lambda x: preferred_order.index(x) if x in preferred_order else len(preferred_order)
        )
        df = df.sort_values(["_order", version_col]).drop(columns="_order").reset_index(drop=True)

        df["delta_vs_prev_s"] = df[total_col].diff()
        df["gain_vs_prev_pct"] = (-df[total_col].pct_change()) * 100
        baseline_time = df[total_col].iloc[0]
        df["speedup_vs_baseline"] = baseline_time / df[total_col]
        df["reduction_vs_baseline_pct"] = (1 - df[total_col] / baseline_time) * 100

        cols_to_show = [version_col, total_col, "delta_vs_prev_s", "gain_vs_prev_pct", "speedup_vs_baseline", "reduction_vs_baseline_pct"]
        cols_to_show = [c for c in cols_to_show if c in df.columns]
        display(df[cols_to_show])

        print(f"\nArquivo usado: {compare_csv}")

# %% [markdown]
# ## 6) Comparação final e escalonamento
#
# Esta é a parte mais importante para fechar o projeto. Aqui, a leitura não é só “qual versão ganhou”, mas sim:
#
# - qual versão fica melhor em tempo absoluto;
# - qual versão entrega o maior ganho marginal;
# - se o ganho se mantém quando a entrada cresce;
# - se a curva de escalabilidade é consistente.
#
# ### O que mostrar no encerramento
# 1. tabela consolidada das versões;
# 2. gráfico de tempo total;
# 3. gráfico de ganho marginal;
# 4. gráfico de escalonamento, se houver dados por tamanho de entrada;
# 5. interpretação final sobre performance e trade-offs.
#
# ### Interpretação esperada
# - a baseline continua sendo a referência de corretude;
# - a vetorização tende a cortar boa parte do custo de loops Python;
# - Numba pode brilhar em trechos computacionais puros, mas tem custo de warm-up;
# - multiprocessing só compensa quando o overhead não domina;
# - GPU faz sentido quando a transferência de dados não anula o paralelismo.

# %%
# Gráficos finais: comparação entre versões e, se existir, escalonamento.

from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

bench_dir = Path("outputs/benchmarks")

def pick_csv(patterns):
    for pattern in patterns:
        matches = sorted(bench_dir.glob(pattern))
        if matches:
            return matches[0]
    return None

def pick_col(frame, candidates):
    cols = list(frame.columns)
    lower_cols = {c.lower(): c for c in cols}
    for cand in candidates:
        for low, original in lower_cols.items():
            if cand in low:
                return original
    return None

# 1) Gráfico da comparação consolidada
compare_csv = pick_csv(["*compare*.csv", "*versions*.csv"])
if compare_csv is not None:
    df = pd.read_csv(compare_csv)
    version_col = pick_col(df, ["version", "versao", "variant", "name"])
    total_col = pick_col(df, ["mean_total_s", "total_s", "tempo_medio_s", "mean_time_s", "avg_total_s"])

    if version_col is not None and total_col is not None:
        plt.figure(figsize=(9, 4))
        plt.bar(df[version_col].astype(str), df[total_col])
        plt.ylabel("Tempo médio (s)")
        plt.title("Comparação de desempenho entre versões")
        plt.xticks(rotation=20, ha="right")
        plt.tight_layout()
        plt.show()

        baseline_time = df[total_col].iloc[0]
        plt.figure(figsize=(9, 4))
        plt.plot(df[version_col].astype(str), baseline_time / df[total_col], marker="o")
        plt.ylabel("Speedup vs baseline")
        plt.title("Ganho relativo por versão")
        plt.xticks(rotation=20, ha="right")
        plt.tight_layout()
        plt.show()
    else:
        print("Não foi possível identificar colunas de versão e tempo no CSV consolidado.")
else:
    print("CSV consolidado não encontrado para gerar os gráficos finais.")

# 2) Escalonamento, se houver um CSV específico com essa informação
scaling_csv = pick_csv(["*scal*.csv", "*scale*.csv", "*throughput*.csv", "*benchmark*.csv"])
if scaling_csv is not None:
    scaling = pd.read_csv(scaling_csv)

    x_col = pick_col(scaling, ["n", "limit", "size", "samples", "images", "batch"])
    y_col = pick_col(scaling, ["mean_total_s", "total_s", "tempo_medio_s", "mean_time_s", "avg_total_s"])
    version_col = pick_col(scaling, ["version", "versao", "variant", "name"])

    if x_col is not None and y_col is not None:
        if version_col is not None:
            plt.figure(figsize=(9, 4))
            for version, g in scaling.groupby(version_col):
                g = g.sort_values(x_col)
                plt.plot(g[x_col], g[y_col], marker="o", label=str(version))
            plt.xlabel(x_col)
            plt.ylabel("Tempo médio (s)")
            plt.title("Escalonamento por versão")
            plt.legend()
            plt.tight_layout()
            plt.show()
        else:
            plt.figure(figsize=(9, 4))
            scaling = scaling.sort_values(x_col)
            plt.plot(scaling[x_col], scaling[y_col], marker="o")
            plt.xlabel(x_col)
            plt.ylabel("Tempo médio (s)")
            plt.title("Escalonamento")
            plt.tight_layout()
            plt.show()
    else:
        print("CSV de escalonamento encontrado, mas não foi possível identificar as colunas automaticamente.")
else:
    print("Nenhum CSV de escalonamento encontrado. Se ainda não tiver gerado essa etapa, rode a bancada correspondente.")

# %% [markdown]
# ## 7) Conclusão
#
# A leitura final do projeto é que a mesma tarefa pode mudar bastante de custo dependendo da forma de implementação.
#
# ### Conclusão que faz sentido defender
# - a baseline é correta, mas lenta;
# - a vetorização costuma trazer ganhos grandes ao reduzir loops em Python;
# - Numba precisa ser medido com cuidado por causa do warm-up;
# - paralelização ajuda quando o overhead não domina;
# - o maior ganho aparece quando a otimização ataca o gargalo certo.
#
# ### Fechamento sugerido para a apresentação
# > “O projeto mostrou que performance não depende apenas da linguagem, mas principalmente da forma como o trabalho é distribuído entre as etapas do pipeline. A comparação entre versões deixou claro onde estão os gargalos e quais estratégias realmente compensam neste problema.”
